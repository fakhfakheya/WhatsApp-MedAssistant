# %%
import pandas as pd
df=pd.read_csv("diseases.csv")
df
# Out:
#                                       name
# 0                         fungal infection
# 1                                  allergy
# 2                                     gerd
# 3                      chronic cholestasis
# 4                            drug reaction
# 5                      peptic ulcer diseae
# 6                                     aids
# 7                                 diabetes
# 8                          gastroenteritis
# 9                         bronchial asthma
# 10                            hypertension
# 11                                migraine
# 12                    cervical spondylosis
# 13            paralysis (brain hemorrhage)
# 14                                jaundice
# 15                                 malaria
# 16                             chicken pox
# 17                                  dengue
# 18                                 typhoid
# 19                             hepatitis a
# 20                             hepatitis b
# ...

# %%
disease_name=df["name"].dropna().unique().tolist()
print("Liste des maladies :", disease_name)
# Out:
# Liste des maladies : ['fungal infection', 'allergy', 'gerd', 'chronic cholestasis', 'drug reaction', 'peptic ulcer diseae', 'aids', 'diabetes', 'gastroenteritis', 'bronchial asthma', 'hypertension', 'migraine', 'cervical spondylosis', 'paralysis (brain hemorrhage)', 'jaundice', 'malaria', 'chicken pox', 'dengue', 'typhoid', 'hepatitis a', 'hepatitis b', 'hepatitis c', 'hepatitis d', 'hepatitis e', 'alcoholic hepatitis', 'tuberculosis', 'common cold', 'pneumonia', 'dimorphic hemmorhoids(piles)', 'heart attack', 'varicose veins', 'hypothyroidism', 'hyperthyroidism', 'hypoglycemia', 'osteoarthristis', 'arthritis', '(vertigo) paroymsal positional vertigo', 'acne', 'urinary tract infection', 'psoriasis', 'impetigo']

# %%
df1=pd.read_csv("precautions.csv")
df1
# Out:
#                                 name
# 0                    stop irritation
# 1           consult nearest hospital
# 2                   stop taking drug
# 3                          follow up
# 4                    avoid oily food
# ..                               ...
# 91                   try acupuncture
# 92  stop eating solid food for while
# 93    try taking small sips of water
# 94             ease back into eating
# 95                       cover mouth
#
# [96 rows x 1 columns]

# %%
preaucation_name=df1["name"].dropna().unique().tolist()
print(preaucation_name)
# Out:
# ['stop irritation', 'consult nearest hospital', 'stop taking drug', 'follow up', 'avoid oily food', 'avoid non veg food', 'keep mosquitos out', 'apply calamine', 'cover area with bandage', 'use ice to compress itching', 'reduce stress', 'exercise', 'eat healthy', 'get proper sleep', 'wash hands with warm soapy water', 'stop bleeding using pressure', 'consult doctor', 'salt baths', 'avoid fatty spicy food', 'avoid lying down after eating', 'maintain healthy weight', 'cold baths', 'anti itch medicine', 'wash hands through', 'medication', 'acetaminophen', 'lie down', 'avoid sudden change in body', 'avoid abrupt head movment', 'relax', 'lie down on side', 'check in pulse', 'drink sugary drinks', 'bath twice', 'drink plenty of water', 'avoid too many products', 'have balanced diet', 'soak affected area in warm water', 'use antibiotics', 'remove scabs with wet compressed cloth', 'meditation', 'consume probiotic food', 'eliminate milk', 'limit alcohol', 'consume witch hazel', 'warm bath wit
# ...

# %%
df2=pd.read_csv("precautions.csv")
symptom_name=df2["name"].dropna().unique().tolist()
print(symptom_name)
# Out:
# ['stop irritation', 'consult nearest hospital', 'stop taking drug', 'follow up', 'avoid oily food', 'avoid non veg food', 'keep mosquitos out', 'apply calamine', 'cover area with bandage', 'use ice to compress itching', 'reduce stress', 'exercise', 'eat healthy', 'get proper sleep', 'wash hands with warm soapy water', 'stop bleeding using pressure', 'consult doctor', 'salt baths', 'avoid fatty spicy food', 'avoid lying down after eating', 'maintain healthy weight', 'cold baths', 'anti itch medicine', 'wash hands through', 'medication', 'acetaminophen', 'lie down', 'avoid sudden change in body', 'avoid abrupt head movment', 'relax', 'lie down on side', 'check in pulse', 'drink sugary drinks', 'bath twice', 'drink plenty of water', 'avoid too many products', 'have balanced diet', 'soak affected area in warm water', 'use antibiotics', 'remove scabs with wet compressed cloth', 'meditation', 'consume probiotic food', 'eliminate milk', 'limit alcohol', 'consume witch hazel', 'warm bath wit
# ...
